# %%
import pandas as pd
import geopandas as gpd
# Out:
# /var/folders/pp/j38mtrcd75z31z4v489trm_00000gn/T/ipykernel_27192/1259499560.py:2: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
pluto = gpd.read_file('Data/MTA/Travel_Time/nyc_hexes_2000ft_4326.zip')

# %%
pluto.plot()
# Out:
# <AxesSubplot: >

# %%
pluto
# Out:
#          longitude       latitude  \
# 0     9.134126e+05  121403.189079
# 1     9.134126e+05  123403.189079
# 2     9.134126e+05  125403.189079
# 3     9.134126e+05  127403.189079
# 4     9.151447e+05  120403.189079
# ...            ...            ...
# 2925  1.065833e+06  215403.189079
# 2926  1.067565e+06  208403.189079
# 2927  1.067565e+06  210403.189079
# 2928  1.067565e+06  212403.189079
# 2929  1.067565e+06  214403.189079
#
#                                                geometry
# 0     POLYGON ((-74.25055 40.49962, -74.25262 40.496...
# 1     POLYGON ((-74.25058 40.50511, -74.25264 40.502...
# 2     POLYGON ((-74.25060 40.51060, -74.25266 40.507...
# 3     POLYGON ((-74.25062 40.51609, -74.25268 40.513...
# 4     POLYGON ((-74.24432 40.49689, -74.24638 40.494...
# ...                                                 ...
# 2925  POLYGON ((-73.70135 40.75752, -73.70345 40.754...
# 2926  POLYGON ((-73.69519 40.73829, -73.69728 40.735...
# ...

# %%
data = pd.read_json("Data/MTA/Travel_Time/json/1.json",orient='index')

# %%
data
# Out:
#         0
# 344    95
# 345   105
# 346   111
# 347   118
# 340    65
# ...   ...
# 478    83
# 479    81
# 2916  724
# 1368  683
# 1369  680
#
# [2930 rows x 1 columns]

# %%
data.loc[1368]
# Out:
# 0    683
# Name: 1368, dtype: int64

# %%
l = [[] for i in range(5)]

# %%
for i in range(10):
    exec(f'var_{i} = 5')

# %%
var_9
# Out:
# 5

# %%
vars
# Out:
# <function vars>

# %%
df2 = pd.DataFrame(0, 
                   columns= ['girl', 'boy'],
                   index=pd.MultiIndex.from_product([['English','Chinese'],
                                                    ['like','dislike']]))

# %%
df2 = pd.DataFrame()

# %%
df2['1'] = pd.read_json("Data/MTA/Travel_Time/json/2.json",orient='index')

# %%
df2
# Out:
#         0    1
# 344    95   87
# 345   105   97
# 346   111  103
# 347   118  110
# 340    65   57
# ...   ...  ...
# 478    83   76
# 479    81   74
# 2916  724  717
# 1368  683  676
# 1369  680  672
#
# [2930 rows x 2 columns]
